# %%
from emnist import list_datasets
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
list_datasets()
# Out:
# Downloading emnist.zip: 536MB [00:48, 11.5MB/s]
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %%
#from emnist import extract_training_samples
from emnist import extract_training_samples

images, labels = extract_training_samples('letters')
images.shape
# Out:
# (124800, 28, 28)

# %%
sample_letter = images[0]
sample_letter_resize = sample_letter.reshape(28, 28)
plt.imshow(sample_letter_resize, cmap='binary')
#plt.axis('off')
plt.show()

# %%
for i in range(100):
    letters_exam = images[i].reshape((28, 28))
    plt.imshow(letters_exam, cmap = 'binary')
    plt.show()
